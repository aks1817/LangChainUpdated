# %% [markdown]
# ### Models Integration With OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ##### OpenAI Model

# %%
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-4.1")

## invoke the model
response=model.invoke("Hello, how are you?")
response.content

# %% [markdown]
# ##### Google Gemini Model

# %%
os.environ['GOOGLE_API_KEY'] = os.getenv('GOOGLE_API_KEY')

from langchain.chat_models import init_chat_model
model=init_chat_model("google_genai:gemini-2.5-flash-lite")

## invoke the model
response=model.invoke("Hello, how are you?")
response.content

# %% [markdown]
# ##### GROQ Model

# %%
os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')

from langchain.chat_models import init_chat_model
model=init_chat_model("groq:llama-3.3-70b-versatile")

## invoke the model
response=model.invoke("Hello, how are you?")
response.content
# Out:
# "Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you might have. How can I help you today?"
